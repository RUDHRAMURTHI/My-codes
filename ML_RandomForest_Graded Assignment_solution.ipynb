# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import json

# %%
Amsterdam = pd.read_json("E:\\Rudhra\\Study for reputation\\Jigsaw acadamy materials\\Mechine learning\\Graded Assignment\\Datasets\\amsterdam.json")

# %%
Amsterdam.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
Amsterdam.shape
# Out:
# (15181, 13)

# %%
Amsterdam.columns
# Out:
# Index(['host_listings_count', 'accommodates', 'bathrooms', 'bedrooms',
#        'guests_included', 'minimum_nights', 'number_of_reviews',
#        'calculated_host_listings_count', 'price', 'latitude', 'longitude',
#        'room_type', 'instant_bookable'],
#       dtype='object')

# %%
with open("E:\\Rudhra\\Study for reputation\\Jigsaw acadamy materials\\Mechine learning\\Graded Assignment\\Datasets\\amsterdam.json") as json_file:
    json_data = json.load(json_file)

# %%
json_data
# Out:
# {'host_listings_count': {'0': 1.0,
#   '1': 1.0,
#   '2': 1.0,
#   '3': 2.0,
#   '4': 1.0,
#   '5': 1.0,
#   '6': 1.0,
#   '7': 1.0,
#   '8': 3.0,
#   '9': 1.0,
#   '10': 1.0,
#   '11': 1.0,
#   '12': 1.0,
#   '13': 1.0,
#   '14': 1.0,
#   '15': 1.0,
#   '16': 1.0,
#   '17': 1.0,
#   '18': 2.0,
#   '19': 1.0,
#   '20': 1.0,
#   '21': 1.0,
#   '22': 1.0,
#   '23': 3.0,
#   '24': 1.0,
#   '25': 1.0,
#   '26': 1.0,
#   '27': 1.0,
#   '28': 1.0,
#   '29': 1.0,
#   '30': 1.0,
#   '31': 1.0,
#   '32': 2.0,
#   '33': 1.0,
#   '34': 3.0,
#   '35': 1.0,
#   '36': 1.0,
#   '37': 1.0,
#   '38': 24.0,
#   '39': 1.0,
#   '40': 1.0,
#   '41': 1.0,
#   '42': 1.0,
#   '43': 2.0,
#   '44': 1.0,
#   '45': 1.0,
#   '46': 36.0,
#   '47': 1.0,
#   '48': 1.0,
#   '49': 1.0,
#   '50': 1.0,
#   '51': 1.0,
#   '52': 1.0,
#   '53': 1.0,
#   '54': 1.0,
#   '55': 2.0,
#   '56': 1.0,
#   '57': 2.0,
#   '58': 1.0,
#   '59': 1.0,
#   '60': 1.0,
#   '61': 1.0,
#   '62': 2.0,
#   '63': 1.0,
#   '64': 1.0,
# ...

# %%
Ams = pd.DataFrame(json_data)

# %%
Ams.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
Ams.shape
# Out:
# (15181, 13)

# %%
Ams.isnull().sum()
# Out:
# host_listings_count                3
# accommodates                       0
# bathrooms                         18
# bedrooms                          12
# guests_included                    0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# price                              0
# latitude                           0
# longitude                          0
# room_type                          0
# instant_bookable                   0
# dtype: int64

# %%
Ams.dtypes
# Out:
# host_listings_count               float64
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# guests_included                     int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# price                              object
# latitude                          float64
# longitude                         float64
# room_type                          object
# instant_bookable                   object
# dtype: object

# %%
Ams["price"].head()
# Out:
# 0       $145.00
# 1        $88.00
# 10      $130.00
# 100      $90.00
# 1000     $39.00
# Name: price, dtype: object

# %%
Ams["price"].tail()
# Out:
# 9995    $105.00
# 9996    $150.00
# 9997    $320.00
# 9998     $55.00
# 9999     $55.00
# Name: price, dtype: object

# %%
Ams["price"] =pd.to_numeric(Ams["price"].str.replace("$","").str.replace(",", ""))

# %%
Ams.dtypes
# Out:
# host_listings_count               float64
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# guests_included                     int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# price                             float64
# latitude                          float64
# longitude                         float64
# room_type                          object
# instant_bookable                   object
# dtype: object

# %%
round(Ams["price"].mean(), 3)
# Out:
# 134.799

# %%
round(Ams["price"].max(), 1)
# Out:
# 3142.0

# %%
Ams["price"].describe()
# Out:
# count    15181.000000
# mean       134.799223
# std         85.751273
# min         19.000000
# 25%         90.000000
# 50%        118.000000
# 75%        150.000000
# max       3142.000000
# Name: price, dtype: float64

# %%
Ams["price"].quantile(np.arange(0,1,0.01))
# Out:
# 0.00     19.0
# 0.01     40.0
# 0.02     45.0
# 0.03     50.0
# 0.04     54.0
# 0.05     57.0
# 0.06     60.0
# 0.07     60.0
# 0.08     65.0
# 0.09     67.0
# 0.10     70.0
# 0.11     70.0
# 0.12     73.0
# 0.13     75.0
# 0.14     75.0
# 0.15     78.0
# 0.16     79.0
# 0.17     80.0
# 0.18     80.0
# 0.19     80.0
# 0.20     83.0
# 0.21     85.0
# 0.22     85.0
# 0.23     86.0
# 0.24     89.0
# 0.25     90.0
# 0.26     90.0
# 0.27     90.0
# 0.28     90.0
# 0.29     95.0
#         ...
# 0.70    149.0
# 0.71    150.0
# 0.72    150.0
# 0.73    150.0
# 0.74    150.0
# 0.75    150.0
# 0.76    155.0
# 0.77    160.0
# 0.78    160.0
# 0.79    169.0
# 0.80    175.0
# 0.81    175.0
# 0.82    179.0
# 0.83    180.0
# 0.84    185.0
# 0.85    190.0
# 0.86    199.0
# 0.87    200.0
# 0.88    200.0
# 0.89    205.2
# 0.90    220.0
# 0.91    225.0
# 0.92    240.0
# 0.93    250.0
# 0.94    250.0
# 0.95    275.0
# 0.96    299.0
# 0.97    320.0
# 0.98    373.4
# 0.99    440.0
# ...

# %%
round(Ams["price"].quantile(0.99), 1)
# Out:
# 440.0

# %%
plt.boxplot(Ams["price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d03f8c7ef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d03f8ad5c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d03f8c7ac8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d03f8adc50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d03f8adf98>],
#  'means': []}

# %%
Ams.price.plot(kind="box")

# %%
(Ams[Ams["price"]> 440.0].shape[0])/(Ams.shape[0])
# Out:
# 0.009880772017653645

# %%
Ams[Ams["price"]> 440.0]
# Out:
#        host_listings_count  accommodates  bathrooms  bedrooms  \
# 10034                  1.0             4        1.5       4.0
# 10037                  2.0             6        1.0       3.0
# 10134                  1.0             6        2.0       4.0
# 10182                  1.0             8        2.0       4.0
# 10245                  2.0             8        3.5       5.0
# 10304                  1.0            10        2.0       5.0
# 10320                  2.0             4        1.0       3.0
# 10385                  2.0             7        2.0       4.0
# 10530                  1.0             4        2.0       2.0
# 10626                103.0             4        1.5       2.0
# 10639                  1.0             9        2.0       4.0
# 10680                  2.0             4        1.0       2.0
# 10706                  1.0             6        3.0       4.0
# 10708                  1.0             5        2.0       3.0
# ...

# %%
Ams = Ams.drop(Ams[Ams["price"]> 440.0].index, axis=0)

# %%
Ams
# Out:
#        host_listings_count  accommodates  bathrooms  bedrooms  \
# 0                      1.0             6        1.0       2.0
# 1                      1.0             2        1.0       1.0
# 10                     1.0             2        1.0       1.0
# 100                    1.0             5        1.0       4.0
# 1000                   1.0             1        1.0       1.0
# 10000                  1.0             3        1.0       2.0
# 10001                 34.0             4        1.0       2.0
# 10002                  1.0             4        1.0       3.0
# 10003                  1.0             4        1.0       1.0
# 10004                  1.0             2        1.0       1.0
# 10005                  1.0             2        1.0       1.0
# 10006                  1.0             2        1.5       1.0
# 10007                  2.0             3        1.0       1.0
# 10008                  1.0             2        1.0       1.0
# ...

# %%
Ams.shape
# Out:
# (15031, 13)

# %%
Ams.price.plot(kind="box")

# %%
Ams.price.describe()
# Out:
# count    15031.000000
# mean       129.974386
# std         63.799025
# min         19.000000
# 25%         89.000000
# 50%        115.000000
# 75%        150.000000
# max        440.000000
# Name: price, dtype: float64

# %%
round(Ams["price"].quantile(0.90), 1)
# Out:
# 210.0

# %%
Ams.isnull().sum()
# Out:
# host_listings_count                3
# accommodates                       0
# bathrooms                         18
# bedrooms                          12
# guests_included                    0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# price                              0
# latitude                           0
# longitude                          0
# room_type                          0
# instant_bookable                   0
# dtype: int64

# %%
Ams.dropna().shape
# Out:
# (14998, 13)

# %%
18+12+3
# Out:
# 33

# %%
15031 - 33
# Out:
# 14998

# %%
Ams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15031 entries, 0 to 9999
# Data columns (total 13 columns):
# host_listings_count               15028 non-null float64
# accommodates                      15031 non-null int64
# bathrooms                         15013 non-null float64
# bedrooms                          15019 non-null float64
# guests_included                   15031 non-null int64
# minimum_nights                    15031 non-null int64
# number_of_reviews                 15031 non-null int64
# calculated_host_listings_count    15031 non-null int64
# price                             15031 non-null float64
# latitude                          15031 non-null float64
# longitude                         15031 non-null float64
# room_type                         15031 non-null object
# instant_bookable                  15031 non-null object
# dtypes: float64(6), int64(5), object(2)
# memory usage: 2.2+ MB

# %%
Ams[Ams["host_listings_count"].isnull()]
# Out:
#        host_listings_count  accommodates  bathrooms  bedrooms  \
# 14498                  NaN             2        1.0       1.0
# 4243                   NaN             2        1.0       1.0
# 7673                   NaN             4        1.0       1.0
#
#        guests_included  minimum_nights  number_of_reviews  \
# 14498                1               1                  1
# 4243                 2               3                 20
# 7673                 1               3                 19
#
#        calculated_host_listings_count  price   latitude  longitude  \
# 14498                               1  119.0  52.378448   4.857322
# 4243                                1   60.0  52.368725   4.927357
# 7673                                1   89.0  52.389669   4.880899
#
#              room_type instant_bookable
# 14498     Private room                f
# 4243   Entire home/apt                f
# 7673   Entire home/apt                f

# %%
Ams[Ams["bathrooms"].isnull()]
# Out:
#        host_listings_count  accommodates  bathrooms  bedrooms  \
# 10096                  3.0             2        NaN       1.0
# 10360                  2.0             2        NaN       1.0
# 11165                  4.0             2        NaN       1.0
# 11969                  1.0             2        NaN       1.0
# 12893                  1.0             2        NaN       1.0
# 1321                   2.0             2        NaN       1.0
# 1324                   2.0             2        NaN       1.0
# 1369                   2.0             3        NaN       2.0
# 14989                  2.0             2        NaN       1.0
# 2561                   3.0             2        NaN       1.0
# 2837                   2.0             2        NaN       1.0
# 345                    1.0             4        NaN       1.0
# 3582                   1.0             1        NaN       1.0
# 4985                   2.0             2        NaN       1.0
# ...

# %%
Ams.dropna().iloc[[4243]]
# Out:
#        host_listings_count  accommodates  bathrooms  bedrooms  \
# 13859                  2.0             1        1.0       1.0
#
#        guests_included  minimum_nights  number_of_reviews  \
# 13859                1               1                  5
#
#        calculated_host_listings_count  price   latitude  longitude  \
# 13859                               2   48.0  52.383487   4.848594
#
#           room_type instant_bookable
# 13859  Private room                f

# %%
Ams[Ams["bedrooms"].isnull()]
# Out:
#        host_listings_count  accommodates  bathrooms  bedrooms  \
# 10069                  1.0             2        1.0       NaN
# 10097                  1.0             2        1.0       NaN
# 10188                  1.0             2        1.0       NaN
# 1852                   1.0             2        1.0       NaN
# 2753                   1.0             2        1.0       NaN
# 4441                   1.0             2        1.0       NaN
# 6967                   1.0             2        0.5       NaN
# 8737                   1.0             2        1.0       NaN
# 8919                   1.0             2        1.0       NaN
# 925                    5.0            13        0.5       NaN
# 9938                   1.0             1        2.0       NaN
# 9987                   1.0             2        1.0       NaN
#
#        guests_included  minimum_nights  number_of_reviews  \
# 10069                1               2                  5
# ...

# %%
Ams = Ams.dropna()

# %%
Ams.shape
# Out:
# (14998, 13)

# %%
Ams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14998 entries, 0 to 9999
# Data columns (total 13 columns):
# host_listings_count               14998 non-null float64
# accommodates                      14998 non-null int64
# bathrooms                         14998 non-null float64
# bedrooms                          14998 non-null float64
# guests_included                   14998 non-null int64
# minimum_nights                    14998 non-null int64
# number_of_reviews                 14998 non-null int64
# calculated_host_listings_count    14998 non-null int64
# price                             14998 non-null float64
# latitude                          14998 non-null float64
# longitude                         14998 non-null float64
# room_type                         14998 non-null object
# instant_bookable                  14998 non-null object
# dtypes: float64(6), int64(5), object(2)
# memory usage: 1.6+ MB

# %%
Ams.isnull().sum()
# Out:
# host_listings_count               0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# guests_included                   0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# price                             0
# latitude                          0
# longitude                         0
# room_type                         0
# instant_bookable                  0
# dtype: int64

# %%
Ams.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
from math import radians, cos, sin, asin,sqrt

# %%
radians(52.361173)
# Out:
# 0.9138748690563568

# %%
Ams.query("latitude == 52.379189 & longitude == 4.899431")
# Out:
# Empty DataFrame
# Columns: [host_listings_count, accommodates, bathrooms, bedrooms, guests_included, minimum_nights, number_of_reviews, calculated_host_listings_count, price, latitude, longitude, room_type, instant_bookable]
# Index: []

# %%
print(np.radians(4.899431))
print(np.radians(52.379189))
# Out:
# 0.0855112024242783
# 0.9141893075743961

# %%
def haversine_np(lon,lat):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    lon, lat = map(np.radians, [lon, lat])

    dlon = np.radians(4.899431) - lon
    dlat = np.radians(52.379189) - lat

    a = np.sin(dlat/2.0)**2 + np.cos(lat) * np.cos(np.radians(52.379189)) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

# %%
Ams["d_centre"] = haversine_np(Ams["longitude"], Ams["latitude"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Ams.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
Ams.sort_values("d_centre", ascending=True).head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 3158                  1.0             2        1.5       1.0                1
# 3168                  1.0             4        1.0       1.0                1
# 2639                  1.0             4        1.0       1.0                2
# 3010                  4.0             2        1.0       1.0                1
# 1860                  1.0             2        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 3158               1                  0                               1
# 3168               1                  0                               1
# 2639               3                 27                               1
# 3010               1                  4                               4
# 1860               1                  9                               1
#
# ...

# %%
Ams.sort_values("d_centre", ascending=True)["price"].head()
# Out:
# 3158     85.0
# 3168     41.0
# 2639    159.0
# 3010    150.0
# 1860    120.0
# Name: price, dtype: float64

# %%
Ams.query("latitude == 52.358465522 & longitude == 4.9338432093")
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 5606                  1.0             4        2.0       2.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 5606               2                  8                               1
#
#       price   latitude  longitude        room_type instant_bookable  d_centre
# 5606  160.0  52.358466   4.933843  Entire home/apt                f  3.279483

# %%
Ams["room_type"].value_counts()
# Out:
# Entire home/apt    11656
# Private room        3278
# Shared room           64
# Name: room_type, dtype: int64

# %%
round(Ams.query("room_type == 'Private room' & d_centre <= 1")["price"].mean(), 1)
# Out:
# 118.1

# %%
Ams.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
Ams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14998 entries, 0 to 9999
# Data columns (total 14 columns):
# host_listings_count               14998 non-null float64
# accommodates                      14998 non-null int64
# bathrooms                         14998 non-null float64
# bedrooms                          14998 non-null float64
# guests_included                   14998 non-null int64
# minimum_nights                    14998 non-null int64
# number_of_reviews                 14998 non-null int64
# calculated_host_listings_count    14998 non-null int64
# price                             14998 non-null float64
# latitude                          14998 non-null float64
# longitude                         14998 non-null float64
# room_type                         14998 non-null object
# instant_bookable                  14998 non-null object
# d_centre                          14998 non-null float64
# dtypes: float64(7), int64(5), object(2)
# memory usage: 2.3+ MB

# %%
Ams.dtypes
# Out:
# host_listings_count               float64
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# guests_included                     int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# price                             float64
# latitude                          float64
# longitude                         float64
# room_type                          object
# instant_bookable                   object
# d_centre                          float64
# dtype: object

# %%
Ams["instant_bookable"].value_counts()
# Out:
# f    12659
# t     2339
# Name: instant_bookable, dtype: int64

# %%
X = Ams.drop("price", axis=1)

# %%
X.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
y = Ams["price"]

# %%
y.head()
# Out:
# 0       145.0
# 1        88.0
# 10      130.0
# 100      90.0
# 1000     39.0
# Name: price, dtype: float64

# %%
X = pd.get_dummies(X)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14998 entries, 0 to 9999
# Data columns (total 16 columns):
# host_listings_count               14998 non-null float64
# accommodates                      14998 non-null int64
# bathrooms                         14998 non-null float64
# bedrooms                          14998 non-null float64
# guests_included                   14998 non-null int64
# minimum_nights                    14998 non-null int64
# number_of_reviews                 14998 non-null int64
# calculated_host_listings_count    14998 non-null int64
# latitude                          14998 non-null float64
# longitude                         14998 non-null float64
# d_centre                          14998 non-null float64
# room_type_Entire home/apt         14998 non-null uint8
# room_type_Private room            14998 non-null uint8
# room_type_Shared room             14998 non-null uint8
# instant_bookable_f                14998 non-null uint8
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30, random_state=200)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10498 entries, 5606 to 11661
# Data columns (total 16 columns):
# host_listings_count               10498 non-null float64
# accommodates                      10498 non-null int64
# bathrooms                         10498 non-null float64
# bedrooms                          10498 non-null float64
# guests_included                   10498 non-null int64
# minimum_nights                    10498 non-null int64
# number_of_reviews                 10498 non-null int64
# calculated_host_listings_count    10498 non-null int64
# latitude                          10498 non-null float64
# longitude                         10498 non-null float64
# d_centre                          10498 non-null float64
# room_type_Entire home/apt         10498 non-null uint8
# room_type_Private room            10498 non-null uint8
# room_type_Shared room             10498 non-null uint8
# instant_bookable_f                10498 non-null uint8
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4500 entries, 6631 to 13124
# Data columns (total 16 columns):
# host_listings_count               4500 non-null float64
# accommodates                      4500 non-null int64
# bathrooms                         4500 non-null float64
# bedrooms                          4500 non-null float64
# guests_included                   4500 non-null int64
# minimum_nights                    4500 non-null int64
# number_of_reviews                 4500 non-null int64
# calculated_host_listings_count    4500 non-null int64
# latitude                          4500 non-null float64
# longitude                         4500 non-null float64
# d_centre                          4500 non-null float64
# room_type_Entire home/apt         4500 non-null uint8
# room_type_Private room            4500 non-null uint8
# room_type_Shared room             4500 non-null uint8
# instant_bookable_f                4500 non-null uint8
# ...

# %%
X_train.tail()
# Out:
#        host_listings_count  accommodates  bathrooms  bedrooms  \
# 6411                   1.0             2        1.0       1.0
# 9228                   1.0             3        1.0       1.0
# 1072                   2.0             2        1.0       1.0
# 8100                   1.0             4        1.0       3.0
# 11661                  1.0             3        1.0       2.0
#
#        guests_included  minimum_nights  number_of_reviews  \
# 6411                 1               6                 34
# 9228                 2               3                  6
# 1072                 2               2                 13
# 8100                 1               2                 27
# 11661                2               3                  3
#
#        calculated_host_listings_count   latitude  longitude  d_centre  \
# 6411                                1  52.354419   4.934173  3.624058
# 9228                                1  52.351166   4.894002  3.135803
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
for w in range(30,600,10):
    clf=RandomForestRegressor(n_estimators=w,oob_score=True,n_jobs=-1,random_state=200, max_features="sqrt")
    clf.fit(X_train,y_train)
    oob=clf.oob_score_
    print('For n_estimators = '+str(w))
    print('OOB score is '+str(oob))
    print('************************')
# Out:
# For n_estimators = 30
# OOB score is 0.5215176474439506
# ************************
# For n_estimators = 40
# OOB score is 0.5324015887957825
# ************************
# For n_estimators = 50
# OOB score is 0.5377749954534121
# ************************
# For n_estimators = 60
# OOB score is 0.5435240080222068
# ************************
# For n_estimators = 70
# OOB score is 0.54580497184314
# ************************
# For n_estimators = 80
# OOB score is 0.5482542501858187
# ************************
# For n_estimators = 90
# OOB score is 0.5502142181809548
# ************************
# For n_estimators = 100
# OOB score is 0.5514972249530051
# ************************
# For n_estimators = 110
# OOB score is 0.5530111499361148
# ************************
# For n_estimators = 120
# OOB score is 0.5529419497133541
# ************************
# For n_estimators = 130
# OOB score is 0.5529259550450614
# ************************
# For n_estimators = 140
# OOB score is 0.5544160210732754
# ...

# %%
clf=RandomForestRegressor(n_estimators=600,oob_score=True,n_jobs=-1,random_state=200, max_features="sqrt")

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='sqrt', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=600, n_jobs=-1,
#                       oob_score=True, random_state=200, verbose=0,
#                       warm_start=False)

# %%
clf.oob_score_
# Out:
# 0.5620878166645558

# %%
clf.feature_importances_
# Out:
# array([0.02243976, 0.18352997, 0.04894435, 0.12755268, 0.05827143,
#        0.03648135, 0.06058377, 0.02418387, 0.1075029 , 0.1153932 ,
#        0.12794799, 0.04115635, 0.03170457, 0.0007071 , 0.00674534,
#        0.00685537])

# %%
imp_feat=pd.Series(clf.feature_importances_,index=X.columns.tolist())

# %%
imp_feat.sort_values(ascending=False)
# Out:
# accommodates                      0.183530
# d_centre                          0.127948
# bedrooms                          0.127553
# longitude                         0.115393
# latitude                          0.107503
# number_of_reviews                 0.060584
# guests_included                   0.058271
# bathrooms                         0.048944
# room_type_Entire home/apt         0.041156
# minimum_nights                    0.036481
# room_type_Private room            0.031705
# calculated_host_listings_count    0.024184
# host_listings_count               0.022440
# instant_bookable_t                0.006855
# instant_bookable_f                0.006745
# room_type_Shared room             0.000707
# dtype: float64

# %%
clf.fit(X_test,y_test)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='sqrt', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=600, n_jobs=-1,
#                       oob_score=True, random_state=200, verbose=0,
#                       warm_start=False)

# %%
clf.oob_score_
# Out:
# 0.5449730194898696

# %%
y_pre = clf.predict(X_test)

# %%
error = y_test - y_pre

# %%
plt.scatter(y_test, error)

# %%
plt.scatter(y_test, y_pre)

# %%
y_test[2000]
# Out:
# 200.0

# %%
y_pre[2000]
# Out:
# 181.465

# %%
plt.hist(y_test)
plt.hist(y_pre)
# Out:
# (array([ 317., 1270., 1370.,  744.,  386.,  213.,   94.,   57.,   42.,
#            7.]), array([ 33.80833333,  68.81583333, 103.82333333, 138.83083333,
#         173.83833333, 208.84583333, 243.85333333, 278.86083333,
#         313.86833333, 348.87583333, 383.88333333]), <a list of 10 Patch objects>)

# %%
plt.hist(error)
# Out:
# (array([1.000e+00, 1.100e+01, 1.530e+02, 1.514e+03, 2.176e+03, 4.370e+02,
#         1.480e+02, 3.200e+01, 2.300e+01, 5.000e+00]),
#  array([-77.55833333, -59.54066667, -41.523     , -23.50533333,
#          -5.48766667,  12.53      ,  30.54766667,  48.56533333,
#          66.583     ,  84.60066667, 102.61833333]),
#  <a list of 10 Patch objects>)

# %%
clf.oob_prediction_[2000]
# Out:
# 149.21917808219177
